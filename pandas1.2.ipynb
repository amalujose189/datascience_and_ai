# %%
import pandas as pd

# %%
df=pd.read_csv("customer_data.csv")

# %%
df.head()
# Out:
#    id  age  gender  income   education region loyalty_status  \
# 0   1   27    Male   40682    Bachelor   East           Gold
# 1   2   29    Male   15317     Masters   West        Regular
# 2   3   37    Male   38849    Bachelor   West         Silver
# 3   4   30    Male   11568  HighSchool  South        Regular
# 4   5   31  Female   46952     College  North        Regular
#
#   purchase_frequency  purchase_amount product_category  promotion_usage  \
# 0           frequent            18249            Books                0
# 1               rare             4557         Clothing                1
# 2               rare            11822         Clothing                0
# 3           frequent             4098             Food                0
# 4         occasional            19685         Clothing                1
#
#    satisfaction_score
# 0                   6
# 1                   6
# 2                   6
# 3                   7
# 4                   5

# %%
df.tail()
# Out:
#            id  age  gender  income   education region loyalty_status  \
# 99995   99996   31  Female   19691     College   West        Regular
# 99996   99997   36    Male   17428  HighSchool  South        Regular
# 99997   99998   29    Male   13222     College   West        Regular
# 99998   99999   31  Female   40093    Bachelor   West        Regular
# 99999  100000   35  Female   22249     College   West         Silver
#
#       purchase_frequency  purchase_amount product_category  promotion_usage  \
# 99995         occasional             7075           Health                0
# 99996               rare             6873           Health                0
# 99997           frequent             5152         Clothing                0
# 99998           frequent            16312           Health                1
# 99999               rare             9426           Health                0
#
#        satisfaction_score
# 99995                   7
# 99996                   5
# ...

# %%
df.info()
#getting non null data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  100000 non-null  int64
#  1   age                 100000 non-null  int64
#  2   gender              100000 non-null  object
#  3   income              100000 non-null  int64
#  4   education           100000 non-null  object
#  5   region              100000 non-null  object
#  6   loyalty_status      100000 non-null  object
#  7   purchase_frequency  100000 non-null  object
#  8   purchase_amount     100000 non-null  int64
#  9   product_category    100000 non-null  object
#  10  promotion_usage     100000 non-null  int64
#  11  satisfaction_score  100000 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 9.2+ MB

# %%
df.describe()
# Out:
#                   id            age         income  purchase_amount  \
# count  100000.000000  100000.000000  100000.000000    100000.000000
# mean    50000.500000      30.003260   27516.269880      9634.790840
# std     28867.657797       4.480535   12996.782587      4799.339449
# min         1.000000      12.000000    5000.000000      1118.000000
# 25%     25000.750000      27.000000   16271.750000      5583.000000
# 50%     50000.500000      30.000000   27584.500000      9452.000000
# 75%     75000.250000      33.000000   38747.250000     13350.000000
# max    100000.000000      49.000000   50000.000000     26204.000000
#
#        promotion_usage  satisfaction_score
# count    100000.000000       100000.000000
# mean          0.300800            5.009650
# std           0.458608            1.038714
# min           0.000000            0.000000
# 25%           0.000000            4.000000
# 50%           0.000000            5.000000
# 75%           1.000000            6.000000
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'income', 'education', 'region',
#        'loyalty_status', 'purchase_frequency', 'purchase_amount',
#        'product_category', 'promotion_usage', 'satisfaction_score'],
#       dtype='object')

# %%
df["age"]
# Out:
# 0        27
# 1        29
# 2        37
# 3        30
# 4        31
#          ..
# 99995    31
# 99996    36
# 99997    29
# 99998    31
# 99999    35
# Name: age, Length: 100000, dtype: int64

# %%
df[["age","income","education"]] #give the columns
# Out:
#        age  income   education
# 0       27   40682    Bachelor
# 1       29   15317     Masters
# 2       37   38849    Bachelor
# 3       30   11568  HighSchool
# 4       31   46952     College
# ...    ...     ...         ...
# 99995   31   19691     College
# 99996   36   17428  HighSchool
# 99997   29   13222     College
# 99998   31   40093    Bachelor
# 99999   35   22249     College
#
# [100000 rows x 3 columns]

# %%
df.loc[df["age"]>30]
# Out:
#            id  age  gender  income   education region loyalty_status  \
# 2           3   37    Male   38849    Bachelor   West         Silver
# 4           5   31  Female   46952     College  North        Regular
# 5           6   38    Male    7347    Bachelor  South         Silver
# 6           7   32  Female    8265    Bachelor  South         Silver
# 10         11   35    Male   43896  HighSchool  South        Regular
# ...       ...  ...     ...     ...         ...    ...            ...
# 99993   99994   37  Female   37380     College  South        Regular
# 99995   99996   31  Female   19691     College   West        Regular
# 99996   99997   36    Male   17428  HighSchool  South        Regular
# 99998   99999   31  Female   40093    Bachelor   West        Regular
# 99999  100000   35  Female   22249     College   West         Silver
#
#       purchase_frequency  purchase_amount product_category  promotion_usage  \
# ...

# %%
df.iloc[0:5,0:3] #index based
# Out:
#    id  age  gender
# 0   1   27    Male
# 1   2   29    Male
# 2   3   37    Male
# 3   4   30    Male
# 4   5   31  Female

# %%
df.isnull().sum()#to find the null values
# Out:
# id                    0
# age                   0
# gender                0
# income                0
# education             0
# region                0
# loyalty_status        0
# purchase_frequency    0
# purchase_amount       0
# product_category      0
# promotion_usage       0
# satisfaction_score    0
# dtype: int64

# %%
df.dropna(subset=["age"]) #it is used when we find that age has null values ,then we are drop the empty rows
# Out:
#            id  age  gender  income   education region loyalty_status  \
# 0           1   27    Male   40682    Bachelor   East           Gold
# 1           2   29    Male   15317     Masters   West        Regular
# 2           3   37    Male   38849    Bachelor   West         Silver
# 3           4   30    Male   11568  HighSchool  South        Regular
# 4           5   31  Female   46952     College  North        Regular
# ...       ...  ...     ...     ...         ...    ...            ...
# 99995   99996   31  Female   19691     College   West        Regular
# 99996   99997   36    Male   17428  HighSchool  South        Regular
# 99997   99998   29    Male   13222     College   West        Regular
# 99998   99999   31  Female   40093    Bachelor   West        Regular
# 99999  100000   35  Female   22249     College   West         Silver
#
#       purchase_frequency  purchase_amount product_category  promotion_usage  \
# ...

# %%
df1=df.head(3)
df2=df.tail(3)
pd.concat([df1,df2]) #concating the values
# Out:
#            id  age  gender  income education region loyalty_status  \
# 0           1   27    Male   40682  Bachelor   East           Gold
# 1           2   29    Male   15317   Masters   West        Regular
# 2           3   37    Male   38849  Bachelor   West         Silver
# 99997   99998   29    Male   13222   College   West        Regular
# 99998   99999   31  Female   40093  Bachelor   West        Regular
# 99999  100000   35  Female   22249   College   West         Silver
#
#       purchase_frequency  purchase_amount product_category  promotion_usage  \
# 0               frequent            18249            Books                0
# 1                   rare             4557         Clothing                1
# 2                   rare            11822         Clothing                0
# 99997           frequent             5152         Clothing                0
# 99998           frequent            16312           Health                1
# ...

# %%
df3=pd.read_csv("netflix_titles.csv")

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df3.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df3.tail()
# Out:
#      show_id   type       title         director  \
# 8801   s8802  Movie     Zinzana  Majid Al Ansari
# 8802   s8803  Movie      Zodiac    David Fincher
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
# 8805   s8806  Movie        Zoom     Peter Hewitt
# 8806   s8807  Movie      Zubaan      Mozez Singh
#
#                                                    cast  \
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                            country         date_added  release_year rating  \
# 8801  United Arab Emirates, Jordan      March 9, 2016          2015  TV-MA
# 8802                 United States  November 20, 2019          2007      R
# 8804                 United States   November 1, 2019          2009      R
# ...

# %%
df3.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
#df3.dropna(subset=["director","cast","country","duration","date_added","rating"],inplace=True)

# %%
df3.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df3.describe()
# Out:
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'income', 'education', 'region',
#        'loyalty_status', 'purchase_frequency', 'purchase_amount',
#        'product_category', 'promotion_usage', 'satisfaction_score'],
#       dtype='object')

# %%
df3.index
# Out:
# Index([   7,    8,    9,   12,   24,   27,   28,   29,   38,   41,
#        ...
#        8792, 8793, 8794, 8798, 8799, 8801, 8802, 8804, 8805, 8806],
#       dtype='int64', length=5332)

# %%
df3.loc[df3["type"] == "Movie"]
# Out:
#      show_id   type         title             director  \
# 7         s8  Movie       Sankofa         Haile Gerima
# 9        s10  Movie  The Starling       Theodore Melfi
# 12       s13  Movie  Je Suis Karl  Christian Schwochow
# 24       s25  Movie         Jeans           S. Shankar
# 27       s28  Movie     Grown Ups         Dennis Dugan
# ...      ...    ...           ...                  ...
# 8801   s8802  Movie       Zinzana      Majid Al Ansari
# 8802   s8803  Movie        Zodiac        David Fincher
# 8804   s8805  Movie    Zombieland      Ruben Fleischer
# 8805   s8806  Movie          Zoom         Peter Hewitt
# 8806   s8807  Movie        Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %%
df3.loc[df3["release_year"]==2009]
# Out:
#      show_id   type                                         title  \
# 58       s59  Movie  Naruto Shippûden the Movie: The Will of Fire
# 115     s116  Movie                                   Bright Star
# 330     s331  Movie             Cloudy with a Chance of Meatballs
# 347     s348  Movie                                     Planet 51
# 415     s416  Movie                      Chhota Bheem aur Krishna
# ...      ...    ...                                           ...
# 8542   s8543  Movie                                The Ugly Truth
# 8664   s8665  Movie                                 Up in the Air
# 8789   s8790  Movie                           You Changed My Life
# 8799   s8800  Movie                                         Zenda
# 8804   s8805  Movie                                    Zombieland
#
#                            director  \
# 58                  Masahiko Murata
# 115                    Jane Campion
# 330   Phil Lord, Christopher Miller
# ...

# %%
df4=pd.read_csv("netflix2_titles.csv")

# %%
df4.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df4["director"].fillna("unknown",inplace=True)

# %%
df4
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
pd.pivot_table(df3,index="country",columns="type",aggfunc="count")
# Out:
#                                                     cast         date_added  \
# type                                               Movie TV Show      Movie
# country
# , France, Algeria                                    1.0     NaN        1.0
# Argentina                                           34.0     1.0       34.0
# Argentina, Brazil, France, Poland, Germany, Den...   1.0     NaN        1.0
# Argentina, Chile                                     2.0     NaN        2.0
# Argentina, Chile, Peru                               1.0     NaN        1.0
# ...                                                  ...     ...        ...
# Uruguay, Guatemala                                   1.0     NaN        1.0
# Uruguay, Spain, Mexico                               1.0     NaN        1.0
# Venezuela                                            1.0     NaN        1.0
# Vietnam                                              7.0     NaN        7.0
# ...

# %%
df3["country"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Out:
# np.int64(0)
